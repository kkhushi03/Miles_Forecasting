# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# display all columns in DFrame

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
KPIs = pd.read_csv('MonthlyKPIs.csv')

KPIs
# Out:
#    Metrics   Flown Miles  Flown Miles MoM     M+M Flown  M+M Flown MoM  \
# 0   Jan-22  9.480121e+09              NaN  1.550936e+08            NaN
# 1   Feb-22  1.168503e+10            0.233  2.280406e+08          0.470
# 2   Mar-22  1.818952e+10            0.557  3.877116e+08          0.700
# 3   Apr-22  1.867820e+10            0.027  4.122818e+08          0.063
# 4   May-22  2.189573e+10            0.172  4.732201e+08          0.148
# 5   Jun-22  2.868063e+10            0.310  5.973484e+08          0.262
# 6   Jul-22  2.929377e+10            0.021  6.584393e+08          0.102
# 7   Aug-22  2.257827e+10           -0.229  5.945114e+08         -0.097
# 8   Sep-22  2.181917e+10           -0.034  5.887392e+08         -0.010
# 9   Oct-22  2.157371e+10           -0.011  6.191624e+08          0.052
# 10  Nov-22  2.262863e+10            0.049  7.512109e+08          0.213
# 11  Dec-22  2.800617e+10            0.238  9.532380e+08          0.269
# ...

# %%
KPIs.columns
# Out:
# Index(['Metrics', 'Flown Miles', 'Flown Miles MoM', 'M+M Flown',
#        'M+M Flown MoM', 'M+M Share of Flown', 'Booked Miles',
#        'Booked Miles MoM', 'M+M Booked Miles', 'M+M Booked Miles MoM',
#        'Booked to Flown Ratio', 'Booked to Flown Ratio MoM',
#        'M+M Booked to M+M Flown Ratio', 'M+M Booked to M+M Flown Ratio MoM',
#        'M+M Share of Booked', 'Everyday Awards (dprt_dt)',
#        'Everyday Awards (dprt_dt) MoM', 'Saver Awards (dprt_dt)',
#        'Saver Awards (dprt_dt) MoM', 'M+M Awards (dprt_dt)',
#        'M+M Awards (dprt_dt) MoM', 'Saver Share (dprt_dt, minus M+M)',
#        'Avg Everyday Miles Price (dprt_dt)',
#        'Avg Everyday Miles Price (dprt_dt) MoM',
#        'Avg Saver Miles Price (dprt_dt)',
#        'Avg Saver Miles Price (dprt_dt) MoM', 'Avg M+M Miles Price (dprt_dt)',
#        'Avg M+M Miles Price (dprt_dt) MoM',
#        'Avg Everyday Reference Fare (dprt_dt, UA Metal)',
# ...

# %%
KPIs = KPIs[['Flown Miles', 
       'M+M Flown',
       'Booked Miles',
       'Everyday Awards (dprt_dt)',
       'Saver Awards (dprt_dt)',
       'M+M Awards (dprt_dt)',
       'Saver Share (dprt_dt, minus M+M)',
       'Avg Everyday Miles Price (dprt_dt)',
       'Avg Saver Miles Price (dprt_dt)',
       'Avg Everyday Reference Fare (dprt_dt, UA Metal)',
       'Avg Saver Reference Fare (dprt_dt, UA Metal)',
       'Avg Business Everyday Miles Price (dprt_dt)',
       'Avg Business Saver Miles Price (dprt_dt)',
       'Avg Business M+M Miles Price (dprt_dt)',
       'Avg Business Everyday Reference Fare (dprt_dt, UA Metal)',
       'Avg Business Saver Reference Fare (dprt_dt, UA Metal)',
       'Avg Mixed Everyday Miles Price (dprt_dt)',
       'Avg Mixed Saver Miles Price (dprt_dt)',
       'Avg Mixed M+M Miles Price (dprt_dt)',
       'Avg Mixed Everyday Reference Fare (dprt_dt, UA Metal)',
       'Avg Mixed Saver Reference Fare (dprt_dt, UA Metal)',
       'Avg Economy Everyday Miles Price (dprt_dt)',
       'Avg Economy Saver Miles Price (dprt_dt)',
       'Avg Economy M+M Miles Price (dprt_dt)',
       'Avg Economy Everyday Reference Fare (dprt_dt, UA Metal)',
       'Avg Economy Saver Reference Fare (dprt_dt, UA Metal)',
       'Gross Revenue','RPMs','ASMs',
       'Peak Flown Months (1 - 4 peak to not-peak)',
       'Peak Booked Months (1 - 4 peak to not-peak)',
       'Business Mix (vs Leisure) (Entity)', '% Saver Availability (90 DFD)',
       '% Saver Availability (60 DFD)', '% Saver Availability (30 DFD)',
       'Actual?']]

# %%
KPIs['Flown Miles'] = KPIs['Flown Miles'].astype(float)
# Out:
# C:\Users\U413835\AppData\Local\Temp\ipykernel_21804\1539126678.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   KPIs['Flown Miles'] = KPIs['Flown Miles'].astype(float)

# %%
KPIs
# Out:
#      Flown Miles     M+M Flown  Booked Miles  Everyday Awards (dprt_dt)  \
# 0   9.480121e+09  1.550936e+08  1.703213e+10                   149137.0
# 1   1.168503e+10  2.280406e+08  2.194689e+10                   184576.0
# 2   1.818952e+10  3.877116e+08  2.733245e+10                   290631.0
# 3   1.867820e+10  4.122818e+08  2.501372e+10                   312766.0
# 4   2.189573e+10  4.732201e+08  2.611944e+10                   365243.0
# 5   2.868063e+10  5.973484e+08  2.327289e+10                   461853.0
# 6   2.929377e+10  6.584393e+08  2.127965e+10                   515660.0
# 7   2.257827e+10  5.945114e+08  2.091495e+10                   410899.0
# 8   2.181917e+10  5.887392e+08  2.223351e+10                   326069.0
# 9   2.157371e+10  6.191624e+08  2.416879e+10                   372425.0
# 10  2.262863e+10  7.512109e+08  2.255093e+10                   345616.0
# 11  2.800617e+10  9.532380e+08  1.967951e+10                   366994.0
# ...

# %%
Actual_KPIs = KPIs.loc[KPIs['Actual?'] == True]

# %%
Actual_KPIs
# Out:
#      Flown Miles     M+M Flown  Booked Miles  Everyday Awards (dprt_dt)  \
# 0   9.480121e+09  1.550936e+08  1.703213e+10                   149137.0
# 1   1.168503e+10  2.280406e+08  2.194689e+10                   184576.0
# 2   1.818952e+10  3.877116e+08  2.733245e+10                   290631.0
# 3   1.867820e+10  4.122818e+08  2.501372e+10                   312766.0
# 4   2.189573e+10  4.732201e+08  2.611944e+10                   365243.0
# 5   2.868063e+10  5.973484e+08  2.327289e+10                   461853.0
# 6   2.929377e+10  6.584393e+08  2.127965e+10                   515660.0
# 7   2.257827e+10  5.945114e+08  2.091495e+10                   410899.0
# 8   2.181917e+10  5.887392e+08  2.223351e+10                   326069.0
# 9   2.157371e+10  6.191624e+08  2.416879e+10                   372425.0
# 10  2.262863e+10  7.512109e+08  2.255093e+10                   345616.0
# 11  2.800617e+10  9.532380e+08  1.967951e+10                   366994.0
# ...

# %%
from sklearn.model_selection import train_test_split

Flown_Miles_Y = Actual_KPIs['Flown Miles']

Data_X = Actual_KPIs.drop('Flown Miles',axis = 1)

# %%
Flown_Miles_Y
# Out:
# 0     9.480121e+09
# 1     1.168503e+10
# 2     1.818952e+10
# 3     1.867820e+10
# 4     2.189573e+10
# 5     2.868063e+10
# 6     2.929377e+10
# 7     2.257827e+10
# 8     2.181917e+10
# 9     2.157371e+10
# 10    2.262863e+10
# 11    2.800617e+10
# 12    1.715815e+10
# 13    1.893300e+10
# 14    2.749573e+10
# 15    2.501514e+10
# 16    2.741150e+10
# 17    3.397704e+10
# 18    3.378087e+10
# 19    2.889500e+10
# 20    2.578558e+10
# 21    2.562426e+10
# 22    2.666919e+10
# 23    3.523061e+10
# 24    2.042200e+10
# 25    2.251391e+10
# 26    3.224894e+10
# 27    2.640864e+10
# Name: Flown Miles, dtype: float64

# %%
Data_X
# Out:
#        M+M Flown  Booked Miles  Everyday Awards (dprt_dt)  \
# 0   1.550936e+08  1.703213e+10                   149137.0
# 1   2.280406e+08  2.194689e+10                   184576.0
# 2   3.877116e+08  2.733245e+10                   290631.0
# 3   4.122818e+08  2.501372e+10                   312766.0
# 4   4.732201e+08  2.611944e+10                   365243.0
# 5   5.973484e+08  2.327289e+10                   461853.0
# 6   6.584393e+08  2.127965e+10                   515660.0
# 7   5.945114e+08  2.091495e+10                   410899.0
# 8   5.887392e+08  2.223351e+10                   326069.0
# 9   6.191624e+08  2.416879e+10                   372425.0
# 10  7.512109e+08  2.255093e+10                   345616.0
# 11  9.532380e+08  1.967951e+10                   366994.0
# 12  5.448655e+08  3.291183e+10                   249231.0
# 13  6.472151e+08  2.901612e+10                   273118.0
# 14  9.561801e+08  2.903910e+10                   416829.0
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(Data_X, Flown_Miles_Y, test_size=0.16666, random_state=42)

# %%
X_train
# Out:
#        M+M Flown  Booked Miles  Everyday Awards (dprt_dt)  \
# 12  5.448655e+08  3.291183e+10                   249231.0
# 17  1.131603e+09  2.588424e+10                   485891.0
# 22  2.740046e+09  2.399347e+10                   361058.0
# 11  9.532380e+08  1.967951e+10                   366994.0
# 13  6.472151e+08  2.901612e+10                   273118.0
# 15  8.474149e+08  2.715855e+10                   385968.0
# 1   2.280406e+08  2.194689e+10                   184576.0
# 4   4.732201e+08  2.611944e+10                   365243.0
# 5   5.973484e+08  2.327289e+10                   461853.0
# 2   3.877116e+08  2.733245e+10                   290631.0
# 16  9.795396e+08  2.753658e+10                   365943.0
# 23  3.598856e+09  2.219021e+10                   396369.0
# 3   4.122818e+08  2.501372e+10                   312766.0
# 26  3.586826e+09  2.934223e+10                   446055.0
# 24  2.054470e+09  3.338260e+10                   256887.0
# ...

# %%
y_train
# Out:
# 12    1.715815e+10
# 17    3.397704e+10
# 22    2.666919e+10
# 11    2.800617e+10
# 13    1.893300e+10
# 15    2.501514e+10
# 1     1.168503e+10
# 4     2.189573e+10
# 5     2.868063e+10
# 2     1.818952e+10
# 16    2.741150e+10
# 23    3.523061e+10
# 3     1.867820e+10
# 26    3.224894e+10
# 24    2.042200e+10
# 18    3.378087e+10
# 27    2.640864e+10
# 20    2.578558e+10
# 7     2.257827e+10
# 10    2.262863e+10
# 14    2.749573e+10
# 19    2.889500e+10
# 6     2.929377e+10
# Name: Flown Miles, dtype: float64

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression


X_train, y_train = make_regression(n_features = 35,random_state=0, shuffle=False)

# %%
regr = RandomForestRegressor(max_depth=2)

# %%
regr = RandomForestRegressor(max_depth=2)

regr.fit(X_train, y_train)

X_test_row1 = X_test.iloc[4]

X_test_row1[0:]
# Out:
# M+M Flown                                                     155093560.417
# Booked Miles                                                17032133611.417
# Everyday Awards (dprt_dt)                                          149137.0
# Saver Awards (dprt_dt)                                             283200.0
# M+M Awards (dprt_dt)                                                25004.0
# Saver Share (dprt_dt, minus M+M)                                      0.655
# Avg Everyday Miles Price (dprt_dt)                                41961.263
# Avg Saver Miles Price (dprt_dt)                                   16040.781
# Avg Everyday Reference Fare (dprt_dt, UA Metal)                     371.345
# Avg Saver Reference Fare (dprt_dt, UA Metal)                        188.896
# Avg Business Everyday Miles Price (dprt_dt)                       68063.716
# Avg Business Saver Miles Price (dprt_dt)                          52337.637
# ...

# %%
X_test_row1 = X_test.iloc[4]

# %%
X_test_row1[0:]
# Out:
# M+M Flown                                                     155093560.417
# Booked Miles                                                17032133611.417
# Everyday Awards (dprt_dt)                                          149137.0
# Saver Awards (dprt_dt)                                             283200.0
# M+M Awards (dprt_dt)                                                25004.0
# Saver Share (dprt_dt, minus M+M)                                      0.655
# Avg Everyday Miles Price (dprt_dt)                                41961.263
# Avg Saver Miles Price (dprt_dt)                                   16040.781
# Avg Everyday Reference Fare (dprt_dt, UA Metal)                     371.345
# Avg Saver Reference Fare (dprt_dt, UA Metal)                        188.896
# Avg Business Everyday Miles Price (dprt_dt)                       68063.716
# Avg Business Saver Miles Price (dprt_dt)                          52337.637
# ...

# %%
print(regr.predict([X_test_row1]))
# Out:
# [207.4969849]

# %%
KPIs.columns
# Out:
# Index(['Flown Miles', 'M+M Flown', 'Booked Miles', 'Everyday Awards (dprt_dt)',
#        'Saver Awards (dprt_dt)', 'M+M Awards (dprt_dt)',
#        'Saver Share (dprt_dt, minus M+M)',
#        'Avg Everyday Miles Price (dprt_dt)', 'Avg Saver Miles Price (dprt_dt)',
#        'Avg Everyday Reference Fare (dprt_dt, UA Metal)',
#        'Avg Saver Reference Fare (dprt_dt, UA Metal)',
#        'Avg Business Everyday Miles Price (dprt_dt)',
#        'Avg Business Saver Miles Price (dprt_dt)',
#        'Avg Business M+M Miles Price (dprt_dt)',
#        'Avg Business Everyday Reference Fare (dprt_dt, UA Metal)',
#        'Avg Business Saver Reference Fare (dprt_dt, UA Metal)',
#        'Avg Mixed Everyday Miles Price (dprt_dt)',
#        'Avg Mixed Saver Miles Price (dprt_dt)',
#        'Avg Mixed M+M Miles Price (dprt_dt)',
#        'Avg Mixed Everyday Reference Fare (dprt_dt, UA Metal)',
#        'Avg Mixed Saver Reference Fare (dprt_dt, UA Metal)',
# ...

# %%
KPIs = KPIs[['Flown Miles', 'M+M Flown', 'Booked Miles', 'Everyday Awards (dprt_dt)',
       'Saver Awards (dprt_dt)', 'M+M Awards (dprt_dt)',
       'Avg Everyday Miles Price (dprt_dt)', 'Avg Saver Miles Price (dprt_dt)',
       'Avg Everyday Reference Fare (dprt_dt, UA Metal)',
       'Avg Saver Reference Fare (dprt_dt, UA Metal)',
       'Avg Economy Everyday Miles Price (dprt_dt)',
       'Avg Economy Saver Miles Price (dprt_dt)',
       'Avg Economy M+M Miles Price (dprt_dt)',
       'RPMs', 'ASMs','Gross Revenue',
       'Business Mix (vs Leisure) (Entity)', '% Saver Availability (90 DFD)',
       '% Saver Availability (60 DFD)', '% Saver Availability (30 DFD)']]

# %%
KPIs
# Out:
#      Flown Miles     M+M Flown  Booked Miles  Everyday Awards (dprt_dt)  \
# 0   9.480121e+09  1.550936e+08  1.703213e+10                   149137.0
# 1   1.168503e+10  2.280406e+08  2.194689e+10                   184576.0
# 2   1.818952e+10  3.877116e+08  2.733245e+10                   290631.0
# 3   1.867820e+10  4.122818e+08  2.501372e+10                   312766.0
# 4   2.189573e+10  4.732201e+08  2.611944e+10                   365243.0
# 5   2.868063e+10  5.973484e+08  2.327289e+10                   461853.0
# 6   2.929377e+10  6.584393e+08  2.127965e+10                   515660.0
# 7   2.257827e+10  5.945114e+08  2.091495e+10                   410899.0
# 8   2.181917e+10  5.887392e+08  2.223351e+10                   326069.0
# 9   2.157371e+10  6.191624e+08  2.416879e+10                   372425.0
# 10  2.262863e+10  7.512109e+08  2.255093e+10                   345616.0
# 11  2.800617e+10  9.532380e+08  1.967951e+10                   366994.0
# ...

# %%
Actual_KPIs = KPIs[:28]

# %%
Actual_KPIs
# Out:
#      Flown Miles     M+M Flown  Booked Miles  Everyday Awards (dprt_dt)  \
# 0   9.480121e+09  1.550936e+08  1.703213e+10                   149137.0
# 1   1.168503e+10  2.280406e+08  2.194689e+10                   184576.0
# 2   1.818952e+10  3.877116e+08  2.733245e+10                   290631.0
# 3   1.867820e+10  4.122818e+08  2.501372e+10                   312766.0
# 4   2.189573e+10  4.732201e+08  2.611944e+10                   365243.0
# 5   2.868063e+10  5.973484e+08  2.327289e+10                   461853.0
# 6   2.929377e+10  6.584393e+08  2.127965e+10                   515660.0
# 7   2.257827e+10  5.945114e+08  2.091495e+10                   410899.0
# 8   2.181917e+10  5.887392e+08  2.223351e+10                   326069.0
# 9   2.157371e+10  6.191624e+08  2.416879e+10                   372425.0
# 10  2.262863e+10  7.512109e+08  2.255093e+10                   345616.0
# 11  2.800617e+10  9.532380e+08  1.967951e+10                   366994.0
# ...

# %%
from sklearn.model_selection import train_test_split

Flown_Miles_Y = Actual_KPIs['Flown Miles']
 
Data_X = Actual_KPIs.drop('Flown Miles',axis = 1)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
print(scaler.fit(Data_X))
# Out:
# StandardScaler()

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
print(scaler.fit(Data_X))

print(scaler.mean_)

transformedX = scaler.transform(Data_X)

transformedX
# Out:
# StandardScaler()
# [1.22145367e+09 2.53141004e+10 3.56528321e+05 3.22866214e+05
#  1.22274357e+05 4.10231081e+04 1.94849164e+04 4.31128357e+02
#  2.61700286e+02 3.04863088e+04 1.66599550e+04 6.95668504e+03
#  1.89474729e+10 2.27213260e+04 3.17823334e+09 2.36285714e-01
#  1.73035714e-01 1.66642857e-01 1.45571429e-01]
# array([[-1.11363123, -2.20476293, -2.33617908, -0.76185831, -1.20745672,
#          0.38759118, -2.06562862, -1.16562258, -2.07410329,  0.8207636 ,
#         -2.03141666, -2.39155661, -2.56808504, -1.9755439 , -2.63623752,
#         -2.16794624,  1.8104603 ,  1.1705223 ,  1.70548158],
#        [-1.03745053, -0.89639292, -1.93697312, -0.83503596, -1.11479062,
#         -2.28833733, -2.56599128, -2.47875585, -2.49180538, -1.72188488,
#         -2.61942805, -2.33330001, -2.54805584, -2.4644334 , -2.61400013,
#         -1.12799234,  1.17735132,  1.48704633,  2.27691719],
#        [-0.87070134,  0.53731023, -0.74230659, -0.5266911 , -0.9350817 ,
# ...

# %%
print(scaler.mean_)
# Out:
# [1.22145367e+09 2.53141004e+10 3.56528321e+05 3.22866214e+05
#  1.22274357e+05 4.10231081e+04 1.94849164e+04 4.31128357e+02
#  2.61700286e+02 3.04863088e+04 1.66599550e+04 6.95668504e+03
#  1.89474729e+10 2.27213260e+04 3.17823334e+09 2.36285714e-01
#  1.73035714e-01 1.66642857e-01 1.45571429e-01]

# %%
transformedX = scaler.transform(Data_X)

# %%
transformedX
# Out:
# array([[-1.11363123, -2.20476293, -2.33617908, -0.76185831, -1.20745672,
#          0.38759118, -2.06562862, -1.16562258, -2.07410329,  0.8207636 ,
#         -2.03141666, -2.39155661, -2.56808504, -1.9755439 , -2.63623752,
#         -2.16794624,  1.8104603 ,  1.1705223 ,  1.70548158],
#        [-1.03745053, -0.89639292, -1.93697312, -0.83503596, -1.11479062,
#         -2.28833733, -2.56599128, -2.47875585, -2.49180538, -1.72188488,
#         -2.61942805, -2.33330001, -2.54805584, -2.4644334 , -2.61400013,
#         -1.12799234,  1.17735132,  1.48704633,  2.27691719],
#        [-0.87070134,  0.53731023, -0.74230659, -0.5266911 , -0.9350817 ,
#         -0.94485742, -1.47620991, -2.20093679, -1.7450582 ,  0.28443325,
#         -1.80373499, -1.08693224, -1.12652033, -1.29855361, -1.18888354,
#          0.10454563,  0.50007196,  0.75328608,  0.65527559],
#        [-0.84504197, -0.07996493, -0.49296479, -1.41108423, -0.90149102,
# ...

# %%
X_train, X_test, y_train, y_test = train_test_split(transformedX, Flown_Miles_Y, test_size=0.2222, random_state=42)

# %%
X_test
# Out:
# array([[-0.62899046, -0.3048949 ,  0.17906963, -0.86609324, -0.45504276,
#         -0.79418041,  0.17586757, -0.73693231, -0.34603253, -1.30060605,
#          0.13702902, -0.84131918, -0.11368541, -0.52030408,  0.05672793,
#          0.79784824, -0.64835828, -0.51281003, -0.3794862 ],
#        [ 1.44517195,  1.25247245, -0.88193123,  0.68930626,  1.30834404,
#         -1.55665461, -0.85468585, -0.01229035, -0.18595423, -1.3237119 ,
#         -0.45516824,  0.56379893, -0.49408246, -0.03081763, -0.50163316,
#          1.26004997,  1.92824801,  1.55898361,  1.16493438],
#        [-0.66076231, -0.82009046, -0.3431119 , -0.72920687, -0.61759635,
#          0.23874314,  0.22239097, -0.34325944, -0.42397776, -1.35725163,
#          0.25931834, -0.84036051, -0.30684001, -0.69031382, -0.25184077,
#          0.56674737, -0.63363481, -0.74300933, -0.51848405],
#        [ 0.80436853, -0.41471706,  0.13050797,  1.01438018,  0.71742854,
# ...

# %%
y_test
# Out:
# 9     2.157371e+10
# 25    2.251391e+10
# 8     2.181917e+10
# 21    2.562426e+10
# 0     9.480121e+09
# 12    1.715815e+10
# 17    3.397704e+10
# Name: Flown Miles, dtype: float64

# %%
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
reg = LinearRegression().fit(X_train, y_train)

# %%
reg.score(X_train, y_train)
# Out:
# 0.9987596842586687

# %%
reg.predict(np.array([X_test[3]]))
# Out:
# array([3.17345211e+10])

# %%
y_test[9]
# Out:
# 21573713159.819

# %%
y_test
# Out:
# 2     23.624111
# 22    24.006775
# 14    24.037297
# 17    24.248951
# 5     24.079488
# 11    24.055691
# 24    23.739878
# Name: Flown Miles, dtype: float64

# %%
X_test[0]
# Out:
# array([-0.62899046, -0.3048949 ,  0.17906963, -0.86609324, -0.45504276,
#        -0.79418041,  0.17586757, -0.73693231, -0.34603253, -1.30060605,
#         0.13702902, -0.84131918, -0.11368541, -0.52030408,  0.79784824,
#        -0.64835828, -0.51281003, -0.3794862 ])

# %%
#Below is test

# %%
import matplotlib.pyplot as plt

plt.rcParams['figure.figsize'] = [15, 15]
KPIs.hist()
# Out:
# array([[<Axes: title={'center': 'Flown Miles'}>,
#         <Axes: title={'center': 'M+M Flown'}>,
#         <Axes: title={'center': 'Booked Miles'}>,
#         <Axes: title={'center': 'Everyday Awards (dprt_dt)'}>],
#        [<Axes: title={'center': 'Saver Awards (dprt_dt)'}>,
#         <Axes: title={'center': 'M+M Awards (dprt_dt)'}>,
#         <Axes: title={'center': 'Avg Everyday Miles Price (dprt_dt)'}>,
#         <Axes: title={'center': 'Avg Saver Miles Price (dprt_dt)'}>],
#        [<Axes: title={'center': 'Avg Everyday Reference Fare (dprt_dt, UA Metal)'}>,
#         <Axes: title={'center': 'Avg Saver Reference Fare (dprt_dt, UA Metal)'}>,
#         <Axes: title={'center': 'Avg Economy Everyday Miles Price (dprt_dt)'}>,
#         <Axes: title={'center': 'Avg Economy Saver Miles Price (dprt_dt)'}>],
#        [<Axes: title={'center': 'Avg Economy M+M Miles Price (dprt_dt)'}>,
#         <Axes: title={'center': 'RPMs'}>,
#         <Axes: title={'center': 'ASMs'}>,
# ...

# %%
# %%script false
# f, ax = plt.subplots(1, 1, figsize=(300, 300))
# sns.heatmap(KPIs.corr(), ax=ax)
# Out:
# Couldn't find program: 'false'

# %%
KPIs.corr()['Flown Miles'].sort_values(ascending=False)[0:20]
# Out:
# Flown Miles                                        1.000000
# RPMs                                               0.917089
# Avg Economy M+M Miles Price (dprt_dt)              0.876525
# Avg Saver Reference Fare (dprt_dt, UA Metal)       0.860098
# ASMs                                               0.856777
# Avg Economy Saver Miles Price (dprt_dt)            0.798882
# Avg Saver Miles Price (dprt_dt)                    0.781256
# M+M Flown                                          0.709966
# Avg Everyday Reference Fare (dprt_dt, UA Metal)    0.618827
# Avg Economy Everyday Miles Price (dprt_dt)         0.521210
# Avg Everyday Miles Price (dprt_dt)                 0.495435
# M+M Awards (dprt_dt)                               0.279339
# Booked Miles                                       0.252852
# Everyday Awards (dprt_dt)                          0.048290
# Business Mix (vs Leisure) (Entity)                 0.014598
# Saver Awards (dprt_dt)                            -0.340851
# ...

# %%
KPIs[:28]
# Out:
#      Flown Miles     M+M Flown  Booked Miles  Everyday Awards (dprt_dt)  \
# 0   9.480121e+09  1.550936e+08  1.703213e+10                   149137.0
# 1   1.168503e+10  2.280406e+08  2.194689e+10                   184576.0
# 2   1.818952e+10  3.877116e+08  2.733245e+10                   290631.0
# 3   1.867820e+10  4.122818e+08  2.501372e+10                   312766.0
# 4   2.189573e+10  4.732201e+08  2.611944e+10                   365243.0
# 5   2.868063e+10  5.973484e+08  2.327289e+10                   461853.0
# 6   2.929377e+10  6.584393e+08  2.127965e+10                   515660.0
# 7   2.257827e+10  5.945114e+08  2.091495e+10                   410899.0
# 8   2.181917e+10  5.887392e+08  2.223351e+10                   326069.0
# 9   2.157371e+10  6.191624e+08  2.416879e+10                   372425.0
# 10  2.262863e+10  7.512109e+08  2.255093e+10                   345616.0
# 11  2.800617e+10  9.532380e+08  1.967951e+10                   366994.0
# ...

# %%
KPIs.columns
# Out:
# Index(['Flown Miles', 'M+M Flown', 'Booked Miles', 'Everyday Awards (dprt_dt)',
#        'Saver Awards (dprt_dt)', 'M+M Awards (dprt_dt)',
#        'Avg Everyday Miles Price (dprt_dt)', 'Avg Saver Miles Price (dprt_dt)',
#        'Avg Everyday Reference Fare (dprt_dt, UA Metal)',
#        'Avg Saver Reference Fare (dprt_dt, UA Metal)',
#        'Avg Economy Everyday Miles Price (dprt_dt)',
#        'Avg Economy Saver Miles Price (dprt_dt)',
#        'Avg Economy M+M Miles Price (dprt_dt)', 'RPMs', 'ASMs',
#        'Business Mix (vs Leisure) (Entity)', '% Saver Availability (90 DFD)',
#        '% Saver Availability (60 DFD)', '% Saver Availability (30 DFD)'],
#       dtype='object')

# %%
Flown_Miles_Y = KPIs['Flown Miles'][:28]

Data_X = KPIs[:28].drop('Flown Miles',axis = 1)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
print(scaler.fit(Data_X))

print(scaler.mean_)

transformedX = scaler.transform(Data_X)

transformedX
# Out:
# StandardScaler()
# [1.22145367e+09 2.53141004e+10 3.56528321e+05 3.22866214e+05
#  1.22274357e+05 4.10231081e+04 1.94849164e+04 4.31128357e+02
#  2.61700286e+02 3.04863088e+04 1.66599550e+04 6.95668504e+03
#  1.89474729e+10 2.27213260e+04 2.36285714e-01 1.73035714e-01
#  1.66642857e-01 1.45571429e-01]
# array([[-1.11363123, -2.20476293, -2.33617908, -0.76185831, -1.20745672,
#          0.38759118, -2.06562862, -1.16562258, -2.07410329,  0.8207636 ,
#         -2.03141666, -2.39155661, -2.56808504, -1.9755439 , -2.16794624,
#          1.8104603 ,  1.1705223 ,  1.70548158],
#        [-1.03745053, -0.89639292, -1.93697312, -0.83503596, -1.11479062,
#         -2.28833733, -2.56599128, -2.47875585, -2.49180538, -1.72188488,
#         -2.61942805, -2.33330001, -2.54805584, -2.4644334 , -1.12799234,
#          1.17735132,  1.48704633,  2.27691719],
#        [-0.87070134,  0.53731023, -0.74230659, -0.5266911 , -0.9350817 ,
# ...

# %%
transformedX[0]
# Out:
# array([-1.11363123, -2.20476293, -2.33617908, -0.76185831, -1.20745672,
#         0.38759118, -2.06562862, -1.16562258, -2.07410329,  0.8207636 ,
#        -2.03141666, -2.39155661, -2.56808504, -1.9755439 , -2.16794624,
#         1.8104603 ,  1.1705223 ,  1.70548158])

# %%
len(transformedX[0])
# Out:
# 18

# %%
df = pd.DataFrame(transformedX, columns=['M+M Flown', 'Booked Miles', 'Everyday Awards (dprt_dt)',
       'Saver Awards (dprt_dt)', 'M+M Awards (dprt_dt)',
       'Avg Everyday Miles Price (dprt_dt)', 'Avg Saver Miles Price (dprt_dt)',
       'Avg Everyday Reference Fare (dprt_dt, UA Metal)',
       'Avg Saver Reference Fare (dprt_dt, UA Metal)',
       'Avg Economy Everyday Miles Price (dprt_dt)',
       'Avg Economy Saver Miles Price (dprt_dt)',
       'Avg Economy M+M Miles Price (dprt_dt)', 'RPMs', 'ASMs',
       'Business Mix (vs Leisure) (Entity)', '% Saver Availability (90 DFD)',
       '% Saver Availability (60 DFD)', '% Saver Availability (30 DFD)'])
print (df)
# Out:
#     M+M Flown  Booked Miles  Everyday Awards (dprt_dt)  \
# 0   -1.113631     -2.204763                  -2.336179
# 1   -1.037451     -0.896393                  -1.936973
# 2   -0.870701      0.537310                  -0.742307
# 3   -0.845042     -0.079965                  -0.492965
# 4   -0.781402      0.214391                   0.098167
# 5   -0.651771     -0.543396                   1.186440
# 6   -0.587972     -1.074021                   1.792554
# 7   -0.654734     -1.171109                   0.612464
# 8   -0.660762     -0.820090                  -0.343112
# 9   -0.628990     -0.304895                   0.179070
# 10  -0.491088     -0.735590                  -0.122923
# 11  -0.280106     -1.499998                   0.117892
# 12  -0.706581      2.022610                  -1.208661
# 13  -0.599694      0.985523                  -0.939583
# 14  -0.277033      0.991643                   0.679263
# 15  -0.390620      0.491016                   0.331626
# ...

# %%
df
# Out:
#     M+M Flown  Booked Miles  Everyday Awards (dprt_dt)  \
# 0   -1.113631     -2.204763                  -2.336179
# 1   -1.037451     -0.896393                  -1.936973
# 2   -0.870701      0.537310                  -0.742307
# 3   -0.845042     -0.079965                  -0.492965
# 4   -0.781402      0.214391                   0.098167
# 5   -0.651771     -0.543396                   1.186440
# 6   -0.587972     -1.074021                   1.792554
# 7   -0.654734     -1.171109                   0.612464
# 8   -0.660762     -0.820090                  -0.343112
# 9   -0.628990     -0.304895                   0.179070
# 10  -0.491088     -0.735590                  -0.122923
# 11  -0.280106     -1.499998                   0.117892
# 12  -0.706581      2.022610                  -1.208661
# 13  -0.599694      0.985523                  -0.939583
# 14  -0.277033      0.991643                   0.679263
# 15  -0.390620      0.491016                   0.331626
# ...

# %%
df_concat = df.insert(0, "FlownMiles", Flown_Miles_Y, True)

# %%
df
# Out:
#       FlownMiles  M+M Flown  Booked Miles  Everyday Awards (dprt_dt)  \
# 0   9.480121e+09  -1.113631     -2.204763                  -2.336179
# 1   1.168503e+10  -1.037451     -0.896393                  -1.936973
# 2   1.818952e+10  -0.870701      0.537310                  -0.742307
# 3   1.867820e+10  -0.845042     -0.079965                  -0.492965
# 4   2.189573e+10  -0.781402      0.214391                   0.098167
# 5   2.868063e+10  -0.651771     -0.543396                   1.186440
# 6   2.929377e+10  -0.587972     -1.074021                   1.792554
# 7   2.257827e+10  -0.654734     -1.171109                   0.612464
# 8   2.181917e+10  -0.660762     -0.820090                  -0.343112
# 9   2.157371e+10  -0.628990     -0.304895                   0.179070
# 10  2.262863e+10  -0.491088     -0.735590                  -0.122923
# 11  2.800617e+10  -0.280106     -1.499998                   0.117892
# 12  1.715815e+10  -0.706581      2.022610                  -1.208661
# ...

# %%
df.corr()['FlownMiles'].sort_values(ascending=False)[0:20]
# Out:
# FlownMiles                                         1.000000
# RPMs                                               0.900477
# Everyday Awards (dprt_dt)                          0.875606
# ASMs                                               0.856777
# Avg Economy M+M Miles Price (dprt_dt)              0.829643
# Avg Economy Saver Miles Price (dprt_dt)            0.803243
# Avg Saver Reference Fare (dprt_dt, UA Metal)       0.802143
# Avg Saver Miles Price (dprt_dt)                    0.705945
# Avg Everyday Reference Fare (dprt_dt, UA Metal)    0.656079
# M+M Flown                                          0.543803
# M+M Awards (dprt_dt)                               0.530981
# Avg Everyday Miles Price (dprt_dt)                 0.376776
# Avg Economy Everyday Miles Price (dprt_dt)         0.294020
# Saver Awards (dprt_dt)                             0.273551
# Booked Miles                                       0.061825
# Business Mix (vs Leisure) (Entity)                 0.055854
# ...

# %%
import numpy as np
from sklearn.linear_model import LassoCV

lasso = LassoCV().fit(X_train, y_train)

MAX_SHOWN_FEATURES = 75
importance = np.abs(lasso.coef_)
feature_names = np.array(X.columns)

importance_df = pd.DataFrame(
    data={ 'importance': importance, 'feature_name': feature_names }
).sort_values("importance", ascending=False).iloc[0:MAX_SHOWN_FEATURES,]

plt.bar(height=importance_df['importance'], x=importance_df['feature_name'])
plt.title("Feature importances via coefficients")
plt.xticks(rotation=90)
plt.show()

# %%
KPIs = pd.read_csv('MonthlyKPIs.csv')

KPIs
# Out:
#    Metrics   Flown Miles  Flown Miles MoM     M+M Flown  M+M Flown MoM  \
# 0   Jan-22  9.480121e+09              NaN  1.550936e+08            NaN
# 1   Feb-22  1.168503e+10            0.233  2.280406e+08          0.470
# 2   Mar-22  1.818952e+10            0.557  3.877116e+08          0.700
# 3   Apr-22  1.867820e+10            0.027  4.122818e+08          0.063
# 4   May-22  2.189573e+10            0.172  4.732201e+08          0.148
# 5   Jun-22  2.868063e+10            0.310  5.973484e+08          0.262
# 6   Jul-22  2.929377e+10            0.021  6.584393e+08          0.102
# 7   Aug-22  2.257827e+10           -0.229  5.945114e+08         -0.097
# 8   Sep-22  2.181917e+10           -0.034  5.887392e+08         -0.010
# 9   Oct-22  2.157371e+10           -0.011  6.191624e+08          0.052
# 10  Nov-22  2.262863e+10            0.049  7.512109e+08          0.213
# 11  Dec-22  2.800617e+10            0.238  9.532380e+08          0.269
# ...

# %%
KPIs
# Out:
#    Metrics   Flown Miles  Flown Miles MoM     M+M Flown  M+M Flown MoM  \
# 0   Jan-22  9.480121e+09              NaN  1.550936e+08            NaN
# 1   Feb-22  1.168503e+10            0.233  2.280406e+08          0.470
# 2   Mar-22  1.818952e+10            0.557  3.877116e+08          0.700
# 3   Apr-22  1.867820e+10            0.027  4.122818e+08          0.063
# 4   May-22  2.189573e+10            0.172  4.732201e+08          0.148
# 5   Jun-22  2.868063e+10            0.310  5.973484e+08          0.262
# 6   Jul-22  2.929377e+10            0.021  6.584393e+08          0.102
# 7   Aug-22  2.257827e+10           -0.229  5.945114e+08         -0.097
# 8   Sep-22  2.181917e+10           -0.034  5.887392e+08         -0.010
# 9   Oct-22  2.157371e+10           -0.011  6.191624e+08          0.052
# 10  Nov-22  2.262863e+10            0.049  7.512109e+08          0.213
# 11  Dec-22  2.800617e+10            0.238  9.532380e+08          0.269
# ...

# %%
KPIs = KPIs[['Flown Miles', 
       'M+M Flown',
       'Booked Miles',
       'Everyday Awards (dprt_dt)',
       'Saver Awards (dprt_dt)',
       'M+M Awards (dprt_dt)',
       'Saver Share (dprt_dt, minus M+M)',
       'Avg Everyday Miles Price (dprt_dt)',
       'Avg Saver Miles Price (dprt_dt)',
       'Avg Everyday Reference Fare (dprt_dt, UA Metal)',
       'Avg Saver Reference Fare (dprt_dt, UA Metal)',
       'Avg Business Everyday Miles Price (dprt_dt)',
       'Avg Business Saver Miles Price (dprt_dt)',
       'Avg Business M+M Miles Price (dprt_dt)',
       'Avg Business Everyday Reference Fare (dprt_dt, UA Metal)',
       'Avg Business Saver Reference Fare (dprt_dt, UA Metal)',
       'Avg Mixed Everyday Miles Price (dprt_dt)',
       'Avg Mixed Saver Miles Price (dprt_dt)',
       'Avg Mixed M+M Miles Price (dprt_dt)',
       'Avg Mixed Everyday Reference Fare (dprt_dt, UA Metal)',
       'Avg Mixed Saver Reference Fare (dprt_dt, UA Metal)',
       'Avg Economy Everyday Miles Price (dprt_dt)',
       'Avg Economy Saver Miles Price (dprt_dt)',
       'Avg Economy M+M Miles Price (dprt_dt)',
       'Avg Economy Everyday Reference Fare (dprt_dt, UA Metal)',
       'Avg Economy Saver Reference Fare (dprt_dt, UA Metal)',
       'Gross Revenue','RPMs','ASMs',
       'Peak Flown Months (1 - 4 peak to not-peak)',
       'Peak Booked Months (1 - 4 peak to not-peak)',
       'Business Mix (vs Leisure) (Entity)', '% Saver Availability (90 DFD)',
       '% Saver Availability (60 DFD)', '% Saver Availability (30 DFD)',
       'Actual?']]

# %%
KPIs = KPIs[:28]
y = KPIs['Flown Miles']

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
KPIs_scaled = pd.DataFrame(
    scaler.fit_transform(KPIs.drop(columns=['Flown Miles'])),
    index=KPIs.index,
    columns=KPIs.drop(columns=['Flown Miles']).columns)

# %%
KPIs_scaled
# Out:
#     M+M Flown  Booked Miles  Everyday Awards (dprt_dt)  \
# 0    0.000000      0.000000                   0.000000
# 1    0.021182      0.300588                   0.093641
# 2    0.067548      0.629971                   0.373871
# 3    0.074682      0.488156                   0.432358
# 4    0.092378      0.555782                   0.571019
# 5    0.128422      0.381687                   0.826292
# 6    0.146162      0.259779                   0.968467
# 7    0.127598      0.237474                   0.691656
# 8    0.125922      0.318118                   0.467509
# 9    0.134756      0.436480                   0.589996
# 10   0.173101      0.337531                   0.519158
# 11   0.231765      0.161914                   0.575645
# 12   0.113182      0.971207                   0.264479
# 13   0.142902      0.732944                   0.327596
# 14   0.232620      0.734350                   0.707325
# 15   0.201036      0.619335                   0.625780
# ...

# %%
KPIs_scaled.describe()
# Out:
#        M+M Flown  Booked Miles  Everyday Awards (dprt_dt)  \
# count  28.000000     28.000000                  28.000000
# mean    0.309650      0.506528                   0.547992
# std     0.283156      0.233958                   0.238872
# min     0.000000      0.000000                   0.000000
# 25%     0.127179      0.332678                   0.404510
# 50%     0.216401      0.484153                   0.571943
# 75%     0.380737      0.647735                   0.694693
# max     1.000000      1.000000                   1.000000
#
#        Saver Awards (dprt_dt)  M+M Awards (dprt_dt)  \
# count               28.000000             28.000000
# mean                 0.512322              0.340553
# std                  0.283665              0.287217
# min                  0.000000              0.000000
# 25%                  0.295008              0.155877
# 50%                  0.550607              0.230017
# 75%                  0.713306              0.421702
# ...

# %%
from sklearn.model_selection import train_test_split

# X = df_properties_scaled.drop(columns=['sell_price'])
#X = KPIs_scaled.drop(columns=['Flown Miles'])
X = KPIs_scaled


# Using 'log' of price for better predictions
#y = np.log(KPIs_scaled['Miles Flown'])
#y = KPIs_scaled['Flown Miles']
ylog = np.log(y)


X_train, X_test, y_train, y_test = train_test_split(X, ylog, random_state=0)

# %%
# https://scikit-learn.org/stable/auto_examples/feature_selection/plot_select_from_model_diabetes.html

import numpy as np
from sklearn.linear_model import LassoCV

lasso = LassoCV().fit(X_train, y_train)

MAX_SHOWN_FEATURES = 75
importance = np.abs(lasso.coef_)
feature_names = np.array(X.columns)

importance_df = pd.DataFrame(
    data={ 'importance': importance, 'feature_name': feature_names }
).sort_values("importance", ascending=False).iloc[0:MAX_SHOWN_FEATURES,]

plt.bar(height=importance_df['importance'], x=importance_df['feature_name'])
plt.title("Feature importances via coefficients")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\U413835\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.813e-04, tolerance: 1.732e-04
#   model = cd_fast.enet_coordinate_descent(

# %%
importance_df
# Out:
#     importance                                       feature_name
# 25    0.475807                                      Gross Revenue
# 22    0.254453              Avg Economy M+M Miles Price (dprt_dt)
# 28    0.172849         Peak Flown Months (1 - 4 peak to not-peak)
# 14    0.135277  Avg Business Saver Reference Fare (dprt_dt, UA...
# 26    0.124932                                               RPMs
# 18    0.082682  Avg Mixed Everyday Reference Fare (dprt_dt, UA...
# 2     0.004370                          Everyday Awards (dprt_dt)
# 20    0.000000         Avg Economy Everyday Miles Price (dprt_dt)
# 21    0.000000            Avg Economy Saver Miles Price (dprt_dt)
# 23    0.000000  Avg Economy Everyday Reference Fare (dprt_dt, ...
# 24    0.000000  Avg Economy Saver Reference Fare (dprt_dt, UA ...
# 0     0.000000                                          M+M Flown
# 19    0.000000  Avg Mixed Saver Reference Fare (dprt_dt, UA Me...
# ...

# %%
KPIs[['Flown Miles','Gross Revenue','Business Mix (vs Leisure) (Entity)']]
# Out:
#      Flown Miles  Gross Revenue  Business Mix (vs Leisure) (Entity)
# 0   9.480121e+09   1.458208e+09                               0.180
# 1   1.168503e+10   1.472717e+09                               0.207
# 2   1.818952e+10   2.402541e+09                               0.239
# 3   1.867820e+10   2.660425e+09                               0.235
# 4   2.189573e+10   3.035198e+09                               0.251
# 5   2.868063e+10   3.659334e+09                               0.229
# 6   2.929377e+10   3.788334e+09                               0.187
# 7   2.257827e+10   3.230674e+09                               0.225
# 8   2.181917e+10   3.013919e+09                               0.251
# 9   2.157371e+10   3.215246e+09                               0.257
# 10  2.262863e+10   3.011724e+09                               0.228
# 11  2.800617e+10   3.203257e+09                               0.193
# 12  1.715815e+10   2.722955e+09                               0.234
# ...

# %%
#Imports

import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.datasets import make_regression

# display all columns in DFrame
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
KPIs = pd.read_csv('MonthlyKPIs.csv')

KPIs
# Out:
#    Metrics   Flown Miles  Flown Miles MoM     M+M Flown  M+M Flown MoM  \
# 0   Jan-22  9.480121e+09              NaN  1.550936e+08            NaN
# 1   Feb-22  1.168503e+10            0.233  2.280406e+08          0.470
# 2   Mar-22  1.818952e+10            0.557  3.877116e+08          0.700
# 3   Apr-22  1.867820e+10            0.027  4.122818e+08          0.063
# 4   May-22  2.189573e+10            0.172  4.732201e+08          0.148
# 5   Jun-22  2.868063e+10            0.310  5.973484e+08          0.262
# 6   Jul-22  2.929377e+10            0.021  6.584393e+08          0.102
# 7   Aug-22  2.257827e+10           -0.229  5.945114e+08         -0.097
# 8   Sep-22  2.181917e+10           -0.034  5.887392e+08         -0.010
# 9   Oct-22  2.157371e+10           -0.011  6.191624e+08          0.052
# 10  Nov-22  2.262863e+10            0.049  7.512109e+08          0.213
# 11  Dec-22  2.800617e+10            0.238  9.532380e+08          0.269
# ...

# %%
KPIs['Flown Miles'] = KPIs['Flown Miles'].astype(float)

# %%
Actual_KPIs = KPIs.loc[KPIs['Actual?'] == True]

# %%
Flown_Miles_Y = Actual_KPIs['Flown Miles']

Data_X = Actual_KPIs.drop('Flown Miles',axis = 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(Data_X, Flown_Miles_Y, test_size=0.16666, random_state=42)

# %%
X_train, y_train = make_regression(n_features = 35,random_state=0, shuffle=False)

# %%
regr = RandomForestRegressor(max_depth=2)

regr.fit(X_train, y_train)

X_test_row1 = X_test.iloc[4]

X_test_row1[0:]
# Out:
# Metrics                                                                  Jan-22
# Flown Miles MoM                                                             NaN
# M+M Flown                                                         155093560.417
# M+M Flown MoM                                                               NaN
# M+M Share of Flown                                                        0.016
# Booked Miles                                                    17032133611.417
# Booked Miles MoM                                                            NaN
# M+M Booked Miles                                                  298001866.417
# M+M Booked Miles MoM                                                        NaN
# Booked to Flown Ratio                                                     1.797
# Booked to Flown Ratio MoM                                                   NaN
# M+M Booked to M+M Flown Ratio                                             1.921
# ...

# %%
KPIs = KPIs[['Flown Miles', 'M+M Flown', 'Booked Miles', 'Everyday Awards (dprt_dt)',
       'Saver Awards (dprt_dt)', 'M+M Awards (dprt_dt)',
       'Avg Everyday Miles Price (dprt_dt)', 'Avg Saver Miles Price (dprt_dt)',
       'Avg Everyday Reference Fare (dprt_dt, UA Metal)',
       'Avg Saver Reference Fare (dprt_dt, UA Metal)',
       'Avg Economy Everyday Miles Price (dprt_dt)',
       'Avg Economy Saver Miles Price (dprt_dt)',
       'Avg Economy M+M Miles Price (dprt_dt)',
       'RPMs', 'ASMs',
       'Business Mix (vs Leisure) (Entity)', '% Saver Availability (90 DFD)',
       '% Saver Availability (60 DFD)', '% Saver Availability (30 DFD)']]

# %%
KPIs
# Out:
#      Flown Miles     M+M Flown  Booked Miles  Everyday Awards (dprt_dt)  \
# 0   9.480121e+09  1.550936e+08  1.703213e+10                   149137.0
# 1   1.168503e+10  2.280406e+08  2.194689e+10                   184576.0
# 2   1.818952e+10  3.877116e+08  2.733245e+10                   290631.0
# 3   1.867820e+10  4.122818e+08  2.501372e+10                   312766.0
# 4   2.189573e+10  4.732201e+08  2.611944e+10                   365243.0
# 5   2.868063e+10  5.973484e+08  2.327289e+10                   461853.0
# 6   2.929377e+10  6.584393e+08  2.127965e+10                   515660.0
# 7   2.257827e+10  5.945114e+08  2.091495e+10                   410899.0
# 8   2.181917e+10  5.887392e+08  2.223351e+10                   326069.0
# 9   2.157371e+10  6.191624e+08  2.416879e+10                   372425.0
# 10  2.262863e+10  7.512109e+08  2.255093e+10                   345616.0
# 11  2.800617e+10  9.532380e+08  1.967951e+10                   366994.0
# ...

# %%
KPIs = KPIs[:28]
y = KPIs['Flown Miles']

# %%
KPIs.corr()['FlownMiles'].sort_values(ascending=False)[0:20]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'FlownMiles'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 KPIs.corr()['FlownMiles'].sort_values(ascending=False)[0:20]
#
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()
KPIs_scaled = pd.DataFrame(
    scaler.fit_transform(KPIs.drop(columns=['Flown Miles'])),
    index=KPIs.index,
    columns=KPIs.drop(columns=['Flown Miles']).columns)

# %%
from sklearn.model_selection import train_test_split

# X = df_properties_scaled.drop(columns=['sell_price'])
#X = KPIs_scaled.drop(columns=['Flown Miles'])
X = KPIs_scaled


# Using 'log' of price for better predictions
#y = np.log(KPIs_scaled['Miles Flown'])
#y = KPIs_scaled['Flown Miles']
ylog = np.log(y)


X_train, X_test, y_train, y_test = train_test_split(X, ylog, random_state=0)

# %%
# https://scikit-learn.org/stable/auto_examples/feature_selection/plot_select_from_model_diabetes.html

import numpy as np
from sklearn.linear_model import LassoCV

lasso = LassoCV().fit(X_train, y_train)

MAX_SHOWN_FEATURES = 75
importance = np.abs(lasso.coef_)
feature_names = np.array(X.columns)

importance_df = pd.DataFrame(
    data={ 'importance': importance, 'feature_name': feature_names }
).sort_values("importance", ascending=False).iloc[0:MAX_SHOWN_FEATURES,]

plt.bar(height=importance_df['importance'], x=importance_df['feature_name'])
plt.title("Feature importances via coefficients")
plt.xticks(rotation=90)
plt.show()
# Out:
# C:\Users\U413835\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 2.162e-04, tolerance: 1.509e-04
#   model = cd_fast.enet_coordinate_descent(
# C:\Users\U413835\anaconda3\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 1.977e-04, tolerance: 1.896e-04
#   model = cd_fast.enet_coordinate_descent(
# ...
